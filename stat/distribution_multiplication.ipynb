# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num=int(1e6)

# %% [markdown]
# ## iid distribution addiction

# %%
x1=np.random.rand(num)
x2=np.random.rand(num)

# %%
plt.hist(x1,density=True)
# Out:
# (array([1.00246099, 0.99655099, 0.99939099, 1.00135099, 1.003881  ,
#         0.99767099, 0.99852099, 1.003591  , 0.99679099, 0.99980099]),
#  array([4.07254700e-07, 1.00000308e-01, 2.00000209e-01, 3.00000110e-01,
#         4.00000011e-01, 4.99999911e-01, 5.99999812e-01, 6.99999713e-01,
#         7.99999614e-01, 8.99999515e-01, 9.99999416e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x1*x2,density=True)
# Out:
# (array([3.30168075, 1.91399982, 1.39483273, 1.06032048, 0.80552985,
#         0.59968001, 0.43113176, 0.29154131, 0.16510257, 0.05271703]),
#  array([1.18203535e-07, 9.98350282e-02, 1.99669938e-01, 2.99504848e-01,
#         3.99339758e-01, 4.99174668e-01, 5.99009578e-01, 6.98844488e-01,
#         7.98679398e-01, 8.98514308e-01, 9.98349218e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# $X_1 ~ Uniform(0,1)$
# $X_2 ~ Uniform(0,1)$
# $Y=X_1+X_2$

# %% [markdown]
# $X_1 ~ Uniform(0,1)$
# $X_2 ~ N(0,1)$
# $Y=X_1+X_2$

# %%
x1=np.random.rand(num)
x2=np.random.randn(num)

# %%
plt.hist(x1*x2,density=True)
# Out:
# (array([5.05598859e-05, 7.10304739e-04, 8.57791625e-03, 6.44354917e-02,
#         3.93157372e-01, 6.56568212e-01, 9.46592049e-02, 1.35648474e-02,
#         1.35525158e-03, 8.87880923e-05]),
#  array([-4.14276099, -3.33184144, -2.52092188, -1.71000233, -0.89908278,
#         -0.08816323,  0.72275632,  1.53367587,  2.34459542,  3.15551498,
#          3.96643453]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# $X=Uniform(0,m=1)$
# $Y=X^2$
# $pdf(Y)=\frac{1}{2m\sqrt{y}}$

# %%
plt.hist(x1**2,density=True)
# Out:
# (array([3.16389246, 1.31224102, 1.00018078, 0.84405066, 0.74889058,
#         0.67346052, 0.61805048, 0.57906045, 0.54477042, 0.5154104 ]),
#  array([5.02218528e-12, 9.99999223e-02, 1.99999845e-01, 2.99999767e-01,
#         3.99999689e-01, 4.99999611e-01, 5.99999534e-01, 6.99999456e-01,
#         7.99999378e-01, 8.99999301e-01, 9.99999223e-01]),
#  <BarContainer object of 10 artists>)

# %%
x = np.linspace(0,1,100)
fit_uni_squared = 1/(2*np.sqrt(x))
plt.plot(x, fit_uni_squared, color='r')
plt.hist(x1**2,density=True)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_27024\3175462230.py:2: RuntimeWarning: divide by zero encountered in divide
#   fit_uni_squared = 1/(2*np.sqrt(x))

# %% [markdown]
# $X=N(0,1)$
# $Y=X^2$
# $Y=\chi^2(1)$
# df=1

# %%
plt.hist(x2**2,density=True)
# Out:
# (array([3.76587756e-01, 4.17808576e-02, 9.82029996e-03, 2.59853868e-03,
#         7.24982792e-04, 1.99920806e-04, 5.48378884e-05, 1.77035703e-05,
#         6.47691595e-06, 3.02256078e-06]),
#  array([1.00372087e-13, 2.31591704e+00, 4.63183408e+00, 6.94775111e+00,
#         9.26366815e+00, 1.15795852e+01, 1.38955022e+01, 1.62114193e+01,
#         1.85273363e+01, 2.08432533e+01, 2.31591704e+01]),
#  <BarContainer object of 10 artists>)

# %%
x3_chi_square=np.random.chisquare(1,num)

# %%
plt.hist(x3_chi_square,density=True)
# Out:
# (array([4.00044873e-01, 4.87863131e-02, 1.27433242e-02, 3.62567857e-03,
#         1.10492870e-03, 3.31898734e-04, 1.13433745e-04, 3.40768039e-05,
#         1.44709715e-05, 6.53527746e-06]),
#  array([1.26520858e-15, 2.14221968e+00, 4.28443936e+00, 6.42665904e+00,
#         8.56887872e+00, 1.07110984e+01, 1.28533181e+01, 1.49955378e+01,
#         1.71377574e+01, 1.92799771e+01, 2.14221968e+01]),
#  <BarContainer object of 10 artists>)
